# %%
import pandas as pd
import matplotlib.pyplot as plt
import lasio
import numpy as np

# %%
las = lasio.read('C:\\Users\\ASUS\\Desktop\\1051661161.LAS')
df = las.df()
print(df.keys())
df['Depth'] = df.index
# Out:
# Index(['AVTX', 'BVTX', 'CILD', 'CNDL', 'CNLS', 'CNPOR', 'CNSS', 'GR', 'LSPD',
#        'LTEN', 'RILD', 'RILM', 'RLL3', 'RXORT', 'SP', 'MCAL', 'MI', 'MN',
#        'ITT', 'DT', 'SPOR', 'DCAL', 'RHOB', 'RHOC', 'DPOR'],
#       dtype='object')

# %%
df.describe()
# Out:
#               AVTX         BVTX         CILD         CNDL         CNLS  \
# count  5541.000000  5541.000000  5540.000000  5466.000000  5466.000000
# mean      0.012272     0.021115   139.910654    18.085643    25.871001
# std       0.119540     0.155831    92.053635     9.482882    11.012485
# min       0.000000     0.000000     0.000000   -10.381000   -27.299300
# 25%       0.000000     0.000000    78.501300    11.179700    20.364025
# 50%       0.000000     0.000000   118.398800    19.443600    28.286950
# 75%       0.000000     0.000000   183.443200    24.192075    32.062125
# max       2.000000     2.000000   674.211400   200.707200   400.581900
#
#              CNPOR         CNSS           GR         LSPD         LTEN  ...  \
# count  5466.000000  5467.000000  5541.000000  5541.000000  5541.000000  ...
# mean     25.780431    28.638905  1580.000000   -68.668264  1102.225995  ...
# std       9.751341     8.460903   799.846626    21.135791   239.228427  ...
# ...

# %%
df.plot(x='Depth', y='CNSS', c='black', lw=0.5, legend=True, figsize=(8,5))

plt.xlim(3000, 200)
plt.ylim(15,50)
plt.title('Plot Without Any Fill')
plt.show()

# %%
df.plot(x='Depth', y='CNSS', c='black', lw=0.5, legend=True, figsize=(8,5))

plt.fill_betweenx(df['CNSS'], df['Depth'], 0, facecolor='green')

plt.xlim(3000, 200)
plt.ylim(15,50)
plt.title('Plot Without Any Fill')
plt.show()

# %%
df.plot(x='Depth', y='CNPOR', c='black', lw=0.5, legend=True, figsize=(8,5))

plt.fill_betweenx(df['CNPOR'], df['Depth'], 0, facecolor='yellow')

plt.xlim(3000, 200)
plt.ylim(8,40)
plt.title('Plot Without Any Fill')
plt.show()

# %%
df.plot(x='Depth', y='RILD', c='black', lw=0.5, legend=True, figsize=(8,5))

plt.fill_betweenx(df['RILD'], df['Depth'], 150, facecolor='red')

plt.xlim(3000, 200)
plt.ylim(25,-5)
plt.title('Plot Without Any Fill')
plt.show()

# %%
df.plot(x='Depth', y='RLL3', c='black', lw=0.5, legend=True, figsize=(8,5))

plt.fill_betweenx(df['RLL3'], df['Depth'], 150, facecolor='green')

plt.xlim(3000, 200)
plt.ylim(1,20)
plt.title('Plot Without Any Fill')
plt.show()

# %%
df.plot(x='Depth', y='RHOB', c='black', lw=0.5, legend=True, figsize=(8,5))

plt.xlim(3000, 200)
plt.ylim(0,10)
plt.title('Plot Without Any Fill')
plt.show()

# %%
df.plot(x='Depth', y='RHOC', c='black', lw=0.5, legend=True, figsize=(8,5))

plt.xlim(3000, 200)
plt.ylim(-2,2)
plt.title('Plot Without Any Fill')
plt.show()
