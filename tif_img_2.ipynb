# %%
from osgeo import gdal
import matplotlib.pyplot as plt
import numpy as np
import imageio

# %%
dataset = gdal.Open('C:\\Users\\ASUS\\Desktop\\berea8bit.tif')

# %%
print(dataset.RasterCount)
# Out:
# 1

# %%
# Load and show image
pic = imageio.imread('C:\\Users\\ASUS\\Desktop\\berea8bit.tif')
plt.imshow(pic)
# Getting basic properties
print('Type of the image : ',type(pic))
print('Shape of the image : {}'.format(pic.shape))
print('Image Height : {}'.format(pic.shape[0]))
print('Image Width : {}'.format(pic.shape[1]))
megapixels = (pic.shape[0]*pic.shape[1]/1000000)
print('Megapixels : {}'.format(megapixels))
print('Dimension of Image : {}'.format(pic.ndim))
# Out:
# C:\Users\ASUS\anaconda3\envs\venv\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
# Type of the image :  <class 'imageio.core.util.Array'>
# Shape of the image : (500, 500)
# Image Height : 500
# Image Width : 500
# Megapixels : 0.25
# Dimension of Image : 2
